# %%
# referência: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sample.html
import pandas as pd
# amostragem aleatoria simples - AASimples
def getSimpleRandomSample(dataFrame, sampleSize):
    # N = len(dataFrame) #tamanho da população
    # n = sampleSize # tamanho da amostra
    # amostra aleatória de índices
    # sampleIndexes = sample(x = 1:N, size = n, replace = FALSE)
    # separando a amostra aleatória correspondente aos índices sorteados
    #sampleData = dataFrame[sampleIndexes, ]
    sampleData = dataFrame.sample(n=sampleSize, replace=False)
    return (sampleData)

# %%
#Exemplo: Conjunto de dados de manutenção
#Ler o conjunto
BD01 = pd.read_csv("../data/BD01.csv", delimiter=";")#, dec = ",", encoding="UTF-8", sep=";", quote="")
#visualizar o conjunto
print(BD01.head(10))
print(BD01.shape)
# Out:
#   Fornecedor Degradacao  TempoFalha  nReincidenciaFalhas
# 0          B       Alto    1.957318                    2
# 1          B       Alto    0.364677                   13
# 2          B      Medio    2.640282                    1
# 3          B       Alto    1.187134                    0
# 4          A      Baixo   18.337973                    4
# 5          A      Baixo   12.536926                   21
# 6          A      Baixo   14.411633                   22
# 7          A      Baixo   18.107021                   60
# 8          A      Baixo   14.849921                   20
# 9          A      Baixo   46.790521                   13
# (579, 4)

# %%
# amostragem aleatoria simples - AASimples
n=5
aaSimples_data = getSimpleRandomSample(dataFrame = BD01, sampleSize = n)
print(aaSimples_data.head(n))
print("************** BD01.describe() **************")
print(BD01.describe())
print("************** aaSimples_data.describe() **************")
print(aaSimples_data.describe())
print("P(sair uma sequência em particluar) = "+str(1/(579*578*577*576)))
# Out:
#     Fornecedor Degradacao  TempoFalha  nReincidenciaFalhas
# 369          A      Baixo   11.221291                    3
# 408          B      Medio    4.706315                    0
# 241          A      Baixo   38.022058                   44
# 163          A      Baixo   66.163469                   49
# 246          A      Baixo   44.101610                    1
# ************** BD01.describe() **************
#        TempoFalha  nReincidenciaFalhas
# count  579.000000           579.000000
# mean    20.250725            18.792746
# std     22.011972            19.226708
# min      0.036110             0.000000
# 25%      2.825574             3.000000
# 50%     14.318828            14.000000
# 75%     30.370120            28.000000
# max    121.861409           125.000000
# ************** aaSimples_data.describe() **************
#        TempoFalha  nReincidenciaFalhas
# count    5.000000              5.00000
# mean    32.842948             19.40000
# std     25.114756             24.82539
# min      4.706315              0.00000
# 25%     11.221291              1.00000
# 50%     38.022058              3.00000
# 75%     44.101610             44.00000
# max     66.163469             49.00000
# P(sair uma sequência em particluar) = 8.990737156241726e-12

# %%
(20.250725 - 22.185802)
# Out:
# -1.9350769999999997

# %%
dataFrame = BD01
N = len(dataFrame)
n = 5
ti = 0
tf = (N-1)  # mínimo e máximo do intervalo de chaves
d = round((tf - ti + 1)/n)  # distância entre índices subsequentes
print("distancia entre individuos: " + str(d))
list(range(22, N, d))
# Out:
# distancia entre individuos: 116
# [22, 138, 254, 370, 486]

# %%
import numpy as np
i0 = np.random.default_rng().integers(low=0, high=d)
# sorteando índices a partir de i0, distanciados por d
sampleIndexes = i0 + list(range(0, N, d))
print('sampleIndexes:', sampleIndexes)
# contornando o problema de índice maior que o máximo possível
#sampleIndexes[sampleIndexes > tf] = sampleIndexes[sampleIndexes > tf] - tf + ti - 1
# separando a amostra aleatória correspondente aos índices sorteados
sampleData = dataFrame.loc[sampleIndexes, ]
print(sampleData)
# Out:
# sampleIndexes: [ 22 138 254 370 486]
#     Fornecedor Degradacao  TempoFalha  nReincidenciaFalhas
# 22           A      Baixo   13.036647                    3
# 138          A      Baixo   12.157323                   28
# 254          B      Medio    3.832867                    4
# 370          A      Baixo   14.104491                   24
# 486          B       Alto    0.187629                   15

# %%
17+58+58+58
# Out:
# 191

# %%
# amostragem aleatoria sistemática - AASistemática
import numpy as np

def getSystematicRandomSample(dataFrame, sampleSize):
    N = len(dataFrame)  # tamanho da população
    n = sampleSize  # tamanho da amostra
    ti = 0
    tf = (N-1)  # mínimo e máximo do intervalo de chaves
    d = round((tf - ti + 1)/n)  # distância entre índices subsequentes
    # primeiro índice sorteado aleatoriamente (como na AASimples)
    i0 = np.random.default_rng().integers(low=0, high=d)
    # sorteando índices a partir de i0, distanciados por d
    sampleIndexes = i0 + list(range(0, N, d))
    # contornando o problema de índice maior que o máximo possível
    #sampleIndexes[sampleIndexes > tf] = sampleIndexes[sampleIndexes > tf] - tf + ti - 1
    # separando a amostra aleatória correspondente aos índices sorteados
    sampleData = dataFrame.loc[sampleIndexes, ]
    print("*********** sampleData ***********")
    print(sampleData)
    return (sampleData)

# %%
n=50
aaSistematica_data = getSystematicRandomSample(dataFrame = BD01, sampleSize = n)
aaSistematica_data.head(2)
print("************** BD01.describe() **************")
print(BD01.describe())
print("************** aaSistematica_data.describe() **************")
print(aaSistematica_data.describe())
# Out:
# *********** sampleData ***********
#     Fornecedor Degradacao  TempoFalha  nReincidenciaFalhas
# 1            B       Alto    0.364677                   13
# 13           B       Alto    0.841063                    1
# 25           A      Baixo   66.780387                   17
# 37           B      Medio    2.507553                   52
# 49           B       Alto    0.785931                   12
# 61           B      Medio    3.803228                   15
# 73           A      Baixo   27.839959                    3
# 85           A      Baixo   18.992856                   11
# 97           A      Baixo   28.932582                   42
# 109          B      Medio    2.261740                   45
# 121          A      Baixo   43.264253                   26
# 133          A      Baixo   10.223242                   17
# 145          A      Baixo   23.473720                   12
# 157          A      Baixo   10.414994                   19
# 169          A      Baixo   22.855791                    2
# 181          B       Alto    0.587859                   13
# 193          A      Baixo   11.734524                    2
# 205          A      Baixo   10.390590                   29
# 217          A      Baixo   35.078385                   12
# 229          B      Medio    3.035702                    0
# 241          A      Baixo   38.022058                   44
# 253          A      Baixo   14.688728                   27
# 265          A      Baixo   13.990066                    3
# 277          A      Baixo   23.783958                    4
# 289          A      Baixo   88.555909                   45
# 301          B       Alto    1.605087                  101
# 313          A      Baixo   10.986034                   15
# 325          A      Baixo   11.203876                   21
# 337          A      Baixo   13.641342                   70
# 349          B       Alto    1.412253                   43
# 361          B      Medio    3.978508                   39
# 373          B      Medio    2.580802                   19
# 385          A      Baixo   18.197455                   13
# 397          A      Baixo   11.099448                   24
# 409          A      Baixo   77.091066                   14
# 421          B       Alto    1.358014                    3
# 433          B       Alto    0.086671                   13
# 445          B      Medio    5.049006                   68
# 457          B      Medio    3.306537                   14
# 469          A      Baixo   22.214682                   38
# 481          A      Baixo   48.129117                   53
# 493          B      Medio    3.463255                   14
# 505          A      Baixo   10.994048                    0
# 517          A      Baixo   20.005969                   38
# 529          A      Baixo   12.739596                    3
# 541          A      Baixo   17.400772                   24
# 553          B      Medio    3.658820                    5
# 565          A      Baixo   42.383497                   65
# 577          A      Baixo   20.160200                    5
# ************** BD01.describe() **************
#        TempoFalha  nReincidenciaFalhas
# count  579.000000           579.000000
# mean    20.250725            18.792746
# std     22.011972            19.226708
# min      0.036110             0.000000
# 25%      2.825574             3.000000
# 50%     14.318828            14.000000
# 75%     30.370120            28.000000
# max    121.861409           125.000000
# ************** aaSistematica_data.describe() **************
#        TempoFalha  nReincidenciaFalhas
# count   49.000000            49.000000
# mean    17.672568            23.836735
# std     19.887364            21.959572
# min      0.086671             0.000000
# 25%      3.306537            11.000000
# 50%     11.203876            15.000000
# 75%     22.855791            38.000000
# max     88.555909           101.000000

# %%
# amostragem aleatoria estratificada proporcional - AAEstrProp
def getProportionalStratifiedRandomSample(dataFrame, sampleSize, stratumVariable):
  # distribuição da variável de estrato na população
  n = sampleSize
  probDist = dataFrame[stratumVariable].value_counts(normalize=True) # View(probDist)
  print('*************** probDist ***************')
  print(probDist)
  # ns = round(n*probDist.values);  # View(ns)
  stratums = probDist.index.to_list()
  nStratums = len(stratums)
  sampleData = pd.DataFrame()
  for i in range(nStratums):
    stratum_i = stratums[i]
    # View(dataFrame_i, title = stratum_i)
    dataFrame_i = dataFrame[dataFrame[stratumVariable] == stratum_i]
    N_i = len(dataFrame_i)  # tamanho da iª população
    n_i = round(n*probDist.values[i])  # tamanho da iª amostra
    # View(sampleData_i, title = paste("amostra_", stratum_i) )
    sampleData_i = getSimpleRandomSample(dataFrame= dataFrame_i, sampleSize= n_i)
    #sampleData_i = getSystematicRandomSample(dataFrame= dataFrame_i, sampleSize= n_i)
    sampleData = pd.concat([sampleData, sampleData_i], axis = 0)
  print('********** sample **********')
  print(sampleData)
  return (sampleData)

# %%
## amostragem aleatoria estratificada proporcional - AAEstrProp
n=10
aaProp_data = getProportionalStratifiedRandomSample(dataFrame=BD01, sampleSize=n, stratumVariable="Degradacao")
#print(aaProp_data.head(n))
print("************** BD01.describe() **************")
print(BD01.describe())
print("************** aaSimples_data.describe() **************")
print(aaProp_data.describe())
# Out:
# *************** probDist ***************
# Degradacao
# Baixo    0.609672
# Alto     0.195164
# Medio    0.195164
# Name: proportion, dtype: float64
# ********** sample **********
#     Fornecedor Degradacao  TempoFalha  nReincidenciaFalhas
# 69           A      Baixo   57.605771                   11
# 547          A      Baixo   36.429944                    3
# 205          A      Baixo   10.390590                   29
# 201          A      Baixo   49.549105                    4
# 488          A      Baixo   15.427958                   74
# 505          A      Baixo   10.994048                    0
# 512          B       Alto    1.255386                   59
# 365          B       Alto    0.657351                   39
# 504          B      Medio    3.791548                    0
# 578          B      Medio    4.885460                    6
# ************** BD01.describe() **************
#        TempoFalha  nReincidenciaFalhas
# count  579.000000           579.000000
# mean    20.250725            18.792746
# std     22.011972            19.226708
# min      0.036110             0.000000
# 25%      2.825574             3.000000
# 50%     14.318828            14.000000
# 75%     30.370120            28.000000
# max    121.861409           125.000000
# ************** aaSimples_data.describe() **************
#        TempoFalha  nReincidenciaFalhas
# count   10.000000            10.000000
# mean    19.098716            22.500000
# std     20.976645            26.746755
# min      0.657351             0.000000
# 25%      4.065026             3.250000
# 50%     10.692319             8.500000
# 75%     31.179447            36.500000
# max     57.605771            74.000000

# %%
#amostragem aleatória simples por mapeamento - AASM
#from numpy.random.Generator import uniform
import numpy as np
def getMapingSimpleRandomSample (bounds, sampleSize):
  bounds = pd.DataFrame(bounds)
  dimensions = bounds.columns
  nDimensions = len(dimensions)
  # N = nrow(dataFrame) #tamanho da população
  n = sampleSize # tamanho da amostra
  #amostra aleatória de coordenadas
  sampleCoordinates = pd.DataFrame()
  for dim_i in dimensions:#i=1
    #amostra aleatória simples para a dimensão dim_i
    rs_i = np.random.default_rng().uniform(size = n, 
                                           low = bounds[dim_i]["min"], 
                                           high = bounds[dim_i]["max"])
    sampleCoordinates[dim_i] = rs_i
  print("*********** sampleCoordinates ***********")
  print(sampleCoordinates)
  return(sampleCoordinates)

# %%
# amostragem aleatória simples por mapeamento - AASM
n=10
bounds = {'lat': {'min': -10, 'max': -1},
          'long': {'min': 15, 'max': 20}, 
          'tempo': {'min': 7, 'max': 22}}
aasm_data = getMapingSimpleRandomSample(bounds = bounds, sampleSize = n)
#aasm_data.head(n)
# Out:
# *********** sampleCoordinates ***********
#         lat       long      tempo
# 0 -2.110966  18.517264   8.311881
# 1 -1.219647  18.419589   7.997675
# 2 -5.603654  16.117064  21.265464
# 3 -4.376772  15.283877   7.603612
# 4 -5.473685  15.329450  10.154185
# 5 -4.789566  18.024404  15.951066
# 6 -2.584204  15.124572  13.783202
# 7 -6.372531  15.552100   9.547890
# 8 -9.134534  15.077088  20.301402
# 9 -4.165899  15.033556  18.252919

# %%
bounds['lat']['min']
# Out:
# -10
